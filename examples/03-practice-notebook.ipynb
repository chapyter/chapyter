# %%
a = 3

# %%
b = 9

# %%
import nbformat

# Load the current notebook
with open("03-practice-notebook.ipynb", "r", encoding="utf-8") as f:
    nb = nbformat.read(f, as_version=4)

# Iterate through each cell
for cell in nb.cells:
    if cell.cell_type == "code":  # Only consider code cells
        # Input
        print("Cell Input:")
        print(cell.source)
        print("\nOutput:")
        
        # Output
        for output in cell.outputs:
            if output.output_type == "stream":
                print(output.text, end="")
            elif "text" in output.data:
                print(output.data["text"], end="")
            else:
                print(output)
        print("="*40)
# Out:
# Cell Input:
# a = 3
#
# Output:
# ========================================
# Cell Input:
# b = 9
#
# Output:
# ========================================
# Cell Input:
# import nbformat
#
# # Load the current notebook
# with open("03-practice-notebook.ipynb", "r", encoding="utf-8") as f:
#     nb = nbformat.read(f, as_version=4)
#
# # Iterate through each cell
# for cell in nb.cells:
#     if cell.cell_type == "code":  # Only consider code cells
#         # Input
#         print("Cell Input:")
#         print(cell.source)
#         print("\nOutput:")
#
#         # Output
#         for output in cell.outputs:
#             if output.output_type == "stream":
#                 print(output.text, end="")
#             elif "text" in output.data:
#                 print(output.data["text"], end="")
#             else:
#                 print(output)
#         print("="*40)
#
#
# Output:
# Cell Input:
# a = 3
#
# Output:
# ========================================
# Cell Input:
# b = 8
#
# Output:
# ========================================
# Cell Input:
# import nbformat
#
# # Load the current notebook
# with open("03-practice-notebook.ipynb", "r", encoding="utf-8") as f:
#     nb = nbformat.read(f, as_version=4)
#
# # Iterate through each cell
# for cell in nb.cells:
#     if cell.cell_type == "code":  # Only consider code cells
#         # Input
#         print("Cell Input:")
#         print(cell.source)
#         print("\nOutput:")
#
#         # Output
#         for output in cell.outputs:
#             if output.output_type == "stream":
#                 print(output.text, end="")
#             elif "text" in output.data:
#                 print(output.data["text"], end="")
#             else:
#                 print(output)
#         print("="*40)
#
#
# Output:
# Cell Input:
# a = 3
#
# Output:
# ========================================
# Cell Input:
# b = 7
#
# Output:
# ========================================
# Cell Input:
# import nbformat
#
# # Load the current notebook
# with open("03-practice-notebook.ipynb", "r", encoding="utf-8") as f:
#     nb = nbformat.read(f, as_version=4)
#
# # Iterate through each cell
# for cell in nb.cells:
#     if cell.cell_type == "code":  # Only consider code cells
#         # Input
#         print("Cell Input:")
#         print(cell.source)
#         print("\nOutput:")
#
#         # Output
#         for output in cell.outputs:
#             if output.output_type == "stream":
#                 print(output.text, end="")
#             elif "text" in output.data:
#                 print(output.data["text"], end="")
#             else:
#                 print(output)
#         print("="*40)
#
#
# Output:
# ========================================
# Cell Input:
#
#
# Output:
# ========================================
# ========================================
# Cell Input:
#
#
# Output:
# ========================================
# ========================================
# Cell Input:
#
#
# Output:
# ========================================
